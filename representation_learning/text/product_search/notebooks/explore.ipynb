# %%
import click
import numpy as np
import logging
import pandas as pd

from constants import DIRECTORY

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


df = pd.read_parquet(f"{DIRECTORY}/test.parquet")

df.head()
# Out:
#     query_id                         query  product_id  \
# 16         2  !qscreen fence without holes  B07D7TBSGH
# 17         2  !qscreen fence without holes  B07DHT2WZK
# 18         2  !qscreen fence without holes  B07DHX8YH2
# 19         2  !qscreen fence without holes  B07DS1YCRZ
# 20         2  !qscreen fence without holes  B07DS3J3MB
#
#                                         product_title  \
# 16  FOTMISHU 6Pcs Greenhouse Hoops Rust-Free Grow ...
# 17  Zippity Outdoor Products ZP19028 Unassembled M...
# 18  Zippity Outdoor Products ZP19026 Lightweight P...
# 19  ColourTree 4' x 50' Green Fence Privacy Screen...
# 20  ColourTree 6' x 50' Black Fence Privacy Screen...
#
#                                   product_description  \
# 16  <p><b>Description:</b><br><b>Material:</b>plas...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
#
#                                  product_bullet_point  \
# 16  ►Material -- High-quality plastic coated steel...
# 17  Designed for the Madison Vinyl Fence (item ZP1...
# 18  Designed as a portable fence for temporary eve...
# 19  ★【Virgin, UV Stabilized Compounds & Thick Mate...
# 20  ★【Virgin, UV Stabilized Compounds & Thick Mate...
#
#                product_brand         product_color  gain
# 16                  FOTMISHU                 green   0.0
# 17  Zippity Outdoor Products                 White   0.0
# 18  Zippity Outdoor Products                 White   1.0
# 19                ColourTree  Green 2nd Generation   0.1
# 20                ColourTree  Black 2nd Generation   0.1

# %%
cols = ["query", "product_brand", "product_title"]
df_c = df[(df.gain == 1) & (df.product_brand.notnull())][cols].sample(1000).copy()
df_c = df_c.applymap(lambda x: x.lower() if isinstance(x, str) else x)
logging.info(df_c.shape)
df_c.sample(5)[cols[:-1]]
# Out:
# INFO:root:(1000, 3)
#                                   query    product_brand
# 63289             adhesive towel bar 3m        ulifestar
# 551843  under armour volleyball spandex     under armour
# 375356                       molle gear         gear aid
# 498410               soccer cleats mens           adidas
# 93938                  banana popsicles  davinci gourmet

# %%
import re


def get_full_matches(row, entity_type="product_brand"):
    entity = row[entity_type]
    query = row["query"]
    present = re.search(r"\b{}\b".format(re.escape(entity)), query)
    if present:
        start = present.start()
        end = present.end()
        start_token = query[:start].count(" ")
        end_token = query[:end].count(" ")
        return {
            "tokenized_text": query.split(" "),
            "ner": [start_token, end_token, entity_type],
        }


df_c["entities"] = df_c.apply(get_full_matches, axis=1)

df_c = df_c[df_c.entities.notnull()]
df_c
# Out:
#                                   query  product_brand  \
# 369087        midol long lasting relief          midol
# 542940    trailer brake controller curt           curt
# 138927         camelbak bite vavle kids       camelbak
# 480352             sesame street sticks  sesame street
# 551843  under armour volleyball spandex   under armour
# ...                                 ...            ...
# 551842  under armour volleyball spandex   under armour
# 151944     chanel lipstick long lasting         chanel
# 274797        hello kitty figurine mini    hello kitty
# 419231                   petzl escalada          petzl
# 63567            adidas joggers for men         adidas
#
#                                             product_title  \
# 369087  midol complete caplets, 24-count (pack of 2), ...
# 542940  curt 51170 spectrum original equipment style, ...
# 138927             camelbak eddy kids bite valves, 4-pack
# 480352  sesame street first books series; big bird's l...
# 551843  under armour women's heatgear armour shorty sh...
# ...                                                   ...
# 551842  under armour women's on the court 3" shorts,bl...
# 151944  rouge coco shine hydrating sheer lipshine - # ...
# 274797   hello kitty crystal kitty doll - limited edition
# 419231         petzl - micro swivel, compact gated swivel
# 63567   adidas men's sereno 19 training pants, black/w...
#
#                                                  entities
# 369087  {'tokenized_text': ['midol', 'long', 'lasting'...
# 542940  {'tokenized_text': ['trailer', 'brake', 'contr...
# 138927  {'tokenized_text': ['camelbak', 'bite', 'vavle...
# 480352  {'tokenized_text': ['sesame', 'street', 'stick...
# 551843  {'tokenized_text': ['under', 'armour', 'volley...
# ...                                                   ...
# 551842  {'tokenized_text': ['under', 'armour', 'volley...
# 151944  {'tokenized_text': ['chanel', 'lipstick', 'lon...
# 274797  {'tokenized_text': ['hello', 'kitty', 'figurin...
# 419231  {'tokenized_text': ['petzl', 'escalada'], 'ner...
# 63567   {'tokenized_text': ['adidas', 'joggers', 'for'...
#
# [112 rows x 4 columns]

# %%
df_c["entities"].to_json("data.json", orient="records")
